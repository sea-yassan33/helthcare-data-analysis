# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import japanize_matplotlib
import seaborn as sns

# %%
## 関数
def plot_service(df):
  df2 = df.copy()
  df2.plot(kind='bar', stacked=True, figsize=(14, 6), colormap='Set3')
  plt.title(f'施設別日常生活自立度_認知状況') 
  plt.xticks(rotation=90, fontsize=10)
  plt.legend(title='ADL(認知)項目', bbox_to_anchor=(1.05, 1), loc='upper left')
  plt.grid(axis='y', linestyle='--', alpha=0.3)
  plt.tight_layout()
  plt.show()
def plot_service2(df):
  df2 = df.copy()
  df2_ratio = df2.div(df2.sum(axis=1), axis=0) * 100
  df2_ratio.plot(kind='bar', stacked=True, figsize=(14, 6), colormap='Set3')
  plt.title(f'施設別日常生活自立度_認知状況の比率') 
  plt.ylabel('比率')
  plt.xticks(rotation=90, fontsize=10)
  plt.legend(title='ADL(認知)項目', bbox_to_anchor=(1.05, 1), loc='upper left')
  plt.grid(axis='y', linestyle='--', alpha=0.3)
  plt.tight_layout()
  plt.show()

# %%
df = pd.read_csv('./data/サービス種類別_日常生活自立度_認知.tsv', sep='\t',index_col=0)
df.head(2)
# Out:
#                  自立      Ⅰ     Ⅱa     Ⅱb      Ⅲa     Ⅲb      Ⅳ      M    不詳
# 介護老人福祉施設       6110  17300  24240  65700  166990  57730  91390  12590  5300
# 地域密着型介護老人福祉施設   710   1900   2470   6490   16260   6200  10170   1290   870

# %%
plot_service(df)

# %%
plot_service2(df)
